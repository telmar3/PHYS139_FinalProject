# %%
import tensorflow as tf
tf.test.is_gpu_available()
# Out:
# 2023-03-23 01:52:03.779484: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-23 01:52:05.733262: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/pkgs/cudnn-8.1.0.77-h90431f1_0/lib/:/opt/conda/pkgs/cudatoolkit-11.2.2-he111cf0_8/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-23 01:52:05.733400: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/pkgs/cudnn-8.1.0.77-h90431f1_0/lib/:/opt/conda/pkgs/cudatoolkit-11.2.2-he111cf0_8/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-23 01:52:05.733417: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING:tensorflow:From /tmp/ipykernel_20506/3326022288.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# 2023-03-23 01:52:08.184773: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-23 01:52:09.344078: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /device:GPU:0 with 10405 MB memory:  -> device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:86:00.0, compute capability: 6.1
# True

# %%
from ipynb.fs.full.data_preprocessing import send_post_processing_params
from ipynb.fs.full.cnn_model_w12 import send_predicted_noise
from scipy.special import logsumexp
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
import math

strain_mean_train, strain_std_train, strain_mean_test, strain_std_test = send_post_processing_params()
noise_predict, tstrain_data_test = send_predicted_noise()
# Out:
# (16781312, 21)
# (16781312,)
# (13425049, 21)
# (13425049,)
# (3356263, 21)
# (3356263,)
# (1638, 8192, 21)
# (1638, 8192)
# (409, 8192, 21)
# (409, 8192)
# Finding pass-band frequencies via Cross Spectral Density Analysis
# Finding pass-band frequencies via Cross Spectral Density Analysis
# Building Butterworth Filter
# Butterworth filter built
# Applying Butterworth to data
# Train Witness shape: (1638, 8192, 21)
# Test Witness shape: (409, 8192, 21)
# Butterworth filter applied to Train data
# Butterworth filter applied to Test data
# Normalization in progress
# CNN Data Ready, Import witness_data
# (1638, 8192, 21)
# Normalization Complete
# Applying Welch's Method
# Welch's Method Complete
# (1638, 8192) (409, 8192)
# (1638, 8192, 21) (1638, 8192) (409, 8192, 21) (409, 8192)
# 2023-03-23 01:54:11.190452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /device:GPU:0 with 10405 MB memory:  -> device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:86:00.0, compute capability: 6.1
# 2023-03-23 01:54:11.258500: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10405 MB memory:  -> device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:86:00.0, compute capability: 6.1
# Model: "deepclean"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 8192, 21)          3108
#
#  batch_normalization (BatchN  (None, 8192, 21)         84
#  ormalization)
#
#  conv1d_1 (Conv1D)           (None, 4096, 8)           1184
#
#  batch_normalization_1 (Batc  (None, 4096, 8)          32
#  hNormalization)
#
#  conv1d_2 (Conv1D)           (None, 2048, 16)          912
#
#  batch_normalization_2 (Batc  (None, 2048, 16)         64
#  hNormalization)
#
#  conv1d_3 (Conv1D)           (None, 1024, 32)          3616
#
#  batch_normalization_3 (Batc  (None, 1024, 32)         128
#  hNormalization)
#
#  conv1d_4 (Conv1D)           (None, 512, 64)           14400
#
#  batch_normalization_4 (Batc  (None, 512, 64)          256
#  hNormalization)
#
#  conv1d_transpose (Conv1DTra  (None, 1024, 32)         14368
#  nspose)
#
#  batch_normalization_5 (Batc  (None, 1024, 32)         128
#  hNormalization)
#
#  conv1d_transpose_1 (Conv1DT  (None, 2048, 16)         3600
#  ranspose)
#
#  batch_normalization_6 (Batc  (None, 2048, 16)         64
#  hNormalization)
#
#  conv1d_transpose_2 (Conv1DT  (None, 4096, 8)          904
#  ranspose)
#
#  batch_normalization_7 (Batc  (None, 4096, 8)          32
#  hNormalization)
#
#  conv1d_transpose_3 (Conv1DT  (None, 8192, 21)         1197
#  ranspose)
#
#  batch_normalization_8 (Batc  (None, 8192, 21)         84
#  hNormalization)
#
#  output (Conv1D)             (None, 8192, 1)           148
#
# =================================================================
# Total params: 44,309
# Trainable params: 43,873
# Non-trainable params: 436
# _________________________________________________________________
# 2023-03-23 01:54:12.096222: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 1014300672 exceeds 10% of free system memory.
# 2023-03-23 01:54:13.700104: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 1014300672 exceeds 10% of free system memory.
# Epoch 1/10
# 2023-03-23 01:54:19.358291: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-03-23 01:54:19.878357: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-23 01:54:20.603823: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x55e8da9ef7c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-03-23 01:54:20.603899: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-03-23 01:54:20.616036: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-03-23 01:54:20.739996: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-23 01:54:20.815515: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-03-23 01:54:20.951853: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-23 01:54:21.169219: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-23 01:54:21.601869: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-23 01:54:21.827387: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-23 01:54:22.246680: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-23 01:54:22.468181: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-23 01:54:22.905841: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-23 01:54:23.131331: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-23 01:54:23.580455: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-23 01:54:23.803633: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
#  2/47 [>.............................] - ETA: 2s - loss: 3.0234
# 2023-03-23 01:54:25.674547: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 47/47 [==============================] - 15s 83ms/step - loss: 1.1557 - val_loss: 1.0277 - lr: 9.0245e-04
# Epoch 2/10
# 47/47 [==============================] - 2s 41ms/step - loss: 0.9997 - val_loss: 1.0282 - lr: 8.1259e-04
# Epoch 3/10
# 47/47 [==============================] - 2s 41ms/step - loss: 0.9985 - val_loss: 1.0301 - lr: 7.3169e-04
# Epoch 4/10
# 47/47 [==============================] - 2s 41ms/step - loss: 0.9981 - val_loss: 1.0353 - lr: 6.5884e-04
# Epoch 5/10
# 47/47 [==============================] - 2s 40ms/step - loss: 0.9979 - val_loss: 1.0427 - lr: 5.9324e-04
# Epoch 6/10
# 47/47 [==============================] - ETA: 0s - loss: 0.9977
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0002670870744623244.
# 47/47 [==============================] - 2s 40ms/step - loss: 0.9977 - val_loss: 1.0497 - lr: 5.3417e-04
# Epoch 7/10
# 47/47 [==============================] - 2s 40ms/step - loss: 0.9976 - val_loss: 1.0553 - lr: 4.8099e-04
# Epoch 8/10
# 47/47 [==============================] - 2s 41ms/step - loss: 0.9975 - val_loss: 1.0616 - lr: 4.3310e-04
# Epoch 9/10
# 47/47 [==============================] - 2s 40ms/step - loss: 0.9975 - val_loss: 1.0665 - lr: 3.8998e-04
# Epoch 10/10
# 47/47 [==============================] - 2s 48ms/step - loss: 0.9974 - val_loss: 1.0693 - lr: 3.5115e-04
# 13/13 [==============================] - 1s 17ms/step
# (409, 8192)

# %%
print(noise_predict.shape, tstrain_data_test.shape)
print(noise_predict.min(), noise_predict.max(), noise_predict.mean())
print(tstrain_data_test.min(), tstrain_data_test.max(), tstrain_data_test.mean())
print(strain_mean_train, strain_std_train, strain_mean_test, strain_std_test)
# Out:
# (409, 8192) (409, 8192)
# -1.4879943 0.88332635 0.022096643
# -4.05966254186472 4.769640788573841 1.3487581060161972e-17
# 9.170753258356378e-25 1.2962399197729473e-19 -7.091983858665298e-24 1.2899310441619718e-19

# %%
model_noise_predict = noise_predict

# %%
#Un-normalizing noise_predict

# Before un-normalization 
plt.plot(model_noise_predict[0])
plt.title('Before inversing z-score')
plt.show()

#Un-normalizing Data
for i in range(noise_predict.shape[0]):
    noise_predict[i] = (noise_predict[i] * strain_std_train) + strain_mean_train
plt.plot(noise_predict[0])
plt.title('After inversing z-score')
plt.show()

plt.plot(model_noise_predict[0], label = 'Normalized')
plt.plot(noise_predict[0], label = 'Un-normalized')
plt.legend()
plt.show()

# %%
model_tstrain_data_test = tstrain_data_test

# %%
#Un-normalizing tstrain_data_test

# Before un-normalization 
plt.plot(model_tstrain_data_test[0])
plt.title('Before inversing z-score')
plt.show()

#Un-normalizing Data
for i in range(tstrain_data_test.shape[0]):
    tstrain_data_test[i] = (tstrain_data_test[i] * strain_std_test) + strain_mean_test
plt.plot(tstrain_data_test[0])
plt.title('After inversing z-score')
plt.show()

plt.plot(model_tstrain_data_test[0], label = 'Normalized')
plt.plot(tstrain_data_test[0], label = 'Un-normalized')
plt.legend()
plt.show()

# %%
#eight-order Butterworth bandpass filter
N = 8
Wn = [0, 0.3] #Band-pass [low end, high end]
filter_type = "bp"
fs = Wn[1]/2
b, a = signal.butter(N, Wn, filter_type, analog=True)
w, h = signal.freqs(b, a)
butter_sos = signal.butter(N, Wn, filter_type, fs , output = 'sos')

# %%
for idx in range(len(noise_predict)):
        noise_predict[idx] = signal.sosfilt(butter_sos, noise_predict[idx])

# %%
plt.plot(noise_predict[0])
plt.title('8th order Butterworth Filter')
plt.show()

# %%
#Flattening noise_predict and original strain
#to subtract and plot

noise_predict = noise_predict.reshape(noise_predict.shape[0]*noise_predict.shape[1])
tstrain_data_test = tstrain_data_test.reshape(tstrain_data_test.shape[0]*tstrain_data_test.shape[1])

# %%
#anti-imaging filter not needed because all samples are sampled at the same rate

#subtracting from full bandwidth strain
clean_strain = tstrain_data_test - noise_predict
plt.plot(clean_strain)
plt.title('Clean Strain')
plt.show()

# %%
#Calculating SNR

P_signal = logsumexp(np.mean(clean_strain ** 2))
P_noise = logsumexp((np.mean(noise_predict) ** 2))
print(P_signal, P_noise)
# Out:
# 1.6639221053313685e-38 1.6543763687424746e-51

# %%
SNR_dB = 10*math.log10(P_signal/P_noise)
print('SNR_dB =',round(SNR_dB,2))
# Out:
# SNR_dB = 130.02

# %%
## Calculating Power Spectral Denisty (PSD) and Amplitude Spectral Density (ASD)

PSD_data_clean = plt.psd(clean_strain, Fs = 4096, scale_by_freq=False)
PSD_data_clean = np.asarray(PSD_data_clean)
plt.xscale("log")
plt.title('PSD of Clean Strain')
# Out:
# Text(0.5, 1.0, 'PSD of Clean Strain')

# %%
PSD_data_orig = plt.psd(tstrain_data_test.reshape(clean_strain.shape), Fs = 4096, scale_by_freq=False,)
PSD_data_orig = np.asarray(PSD_data_orig)
plt.xscale("log")
plt.title('PSD of Original Data')
# Out:
# Text(0.5, 1.0, 'PSD of Original Data')

# %%
#Calculate PSD Difference between Original and Clean Strain

plt.plot(PSD_data_clean[1],np.asarray(PSD_data_orig[0])- np.asarray(PSD_data_clean[0]))
plt.xscale('log')
plt.title('Difference')
# Out:
# Text(0.5, 1.0, 'Difference')

# %%
ASD_data_clean = np.sqrt(PSD_data_clean[0])
plt.semilogx(PSD_data_clean[1],np.log(ASD_data_clean))
plt.grid()
plt.xlabel('Frequency')
plt.ylabel('Amplitude Spectral Density (dB)')
plt.title('ASD of Clean Strain')
# Out:
# Text(0.5, 1.0, 'ASD of Clean Strain')

# %%
ASD_data_orig = np.sqrt(PSD_data_orig[0])
plt.semilogx(PSD_data_orig[1],np.log(ASD_data_orig))
plt.grid()
plt.xlabel('Frequency')
plt.ylabel('Amplitude Spectral Density (dB)')
plt.title('ASD of Original Strain')
# Out:
# Text(0.5, 1.0, 'ASD of Original Strain')

# %%
#Calculate ASD Difference between Original and Clean Strain

plt.plot(PSD_data_clean[1],np.asarray(ASD_data_orig)- np.asarray(ASD_data_clean))
plt.xscale('log')
plt.title('Difference')
# Out:
# Text(0.5, 1.0, 'Difference')

# %%
ASD_ratio = np.asarray(ASD_data_orig)/np.asarray(ASD_data_clean)

# %%
#Calculating ASD ratio between Original/Clean

plt.plot(ASD_ratio)
plt.xscale('log')
plt.title('Original/Clean ASD Ratio')
# Out:
# Text(0.5, 1.0, 'Original/Clean ASD Ratio')
