# %%
from ipynb.fs.full.data_preprocessing import send_post_processing_params
from ipynb.fs.full.cnn_model_w11_1 import send_predicted_noise
from scipy.special import logsumexp
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
import math

strain_mean, strain_std = send_post_processing_params()
noise_predict, time_strain_data, y_test_batch = send_predicted_noise()
# Out:
# (16781312, 21)
# (16781312,)
# (1000, 8192, 21)
# (1000, 8192)
# Finding pass-band frequencies via Cross Spectral Density Analysis
# Finding pass-band frequencies via Cross Spectral Density Analysis
# Building Butterworth Filter
# Butterworth filter built
# Applying Butterworth to data
# (1000, 8192, 21)
# Butterworth filter applied to data
# Normalization in progress
# CNN Data Ready, Import witness_data
# (1000, 8192, 21)
# Normalization Complete
# Applying Welch's Method
# Welch's Method Complete
# (16781312, 21)
# (16781312,)
# (13425049, 21)
# (13425049,)
# (3356263, 21)
# (3356263,)
# (1638, 8192, 21)
# (1638, 8192)
# (409, 8192, 21)
# (409, 8192)
# (1000, 8192, 21) (1000, 8192, 21) (8192000, 1) (8192000, 1)
# (1638, 8192, 21) (1638, 8192) (409, 8192, 21) (409, 8192)
# 2023-03-20 19:46:36.627131: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-20 19:46:37.768557: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/pkgs/cudnn-8.1.0.77-h90431f1_0/lib/:/opt/conda/pkgs/cudatoolkit-11.2.2-he111cf0_8/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-20 19:46:37.768683: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/pkgs/cudnn-8.1.0.77-h90431f1_0/lib/:/opt/conda/pkgs/cudatoolkit-11.2.2-he111cf0_8/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-20 19:46:37.768698: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-20 19:46:38.962454: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-20 19:46:39.993203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10405 MB memory:  -> device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:08:00.0, compute capability: 6.1
# Model: "attempt_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 8192, 21)          2226
#
#  batch_normalization (BatchN  (None, 8192, 21)         84
#  ormalization)
#
#  conv1d_1 (Conv1D)           (None, 4096, 8)           848
#
#  batch_normalization_1 (Batc  (None, 4096, 8)          32
#  hNormalization)
#
#  conv1d_2 (Conv1D)           (None, 2048, 16)          656
#
#  batch_normalization_2 (Batc  (None, 2048, 16)         64
#  hNormalization)
#
#  conv1d_3 (Conv1D)           (None, 1024, 32)          2592
#
#  batch_normalization_3 (Batc  (None, 1024, 32)         128
#  hNormalization)
#
#  conv1d_4 (Conv1D)           (None, 512, 64)           10304
#
#  batch_normalization_4 (Batc  (None, 512, 64)          256
#  hNormalization)
#
#  conv1d_transpose (Conv1DTra  (None, 1024, 32)         10272
#  nspose)
#
#  batch_normalization_5 (Batc  (None, 1024, 32)         128
#  hNormalization)
#
#  conv1d_transpose_1 (Conv1DT  (None, 2048, 16)         2576
#  ranspose)
#
#  batch_normalization_6 (Batc  (None, 2048, 16)         64
#  hNormalization)
#
#  conv1d_transpose_2 (Conv1DT  (None, 4096, 8)          648
#  ranspose)
#
#  batch_normalization_7 (Batc  (None, 4096, 8)          32
#  hNormalization)
#
#  conv1d_transpose_3 (Conv1DT  (None, 8192, 21)         861
#  ranspose)
#
#  batch_normalization_8 (Batc  (None, 8192, 21)         84
#  hNormalization)
#
#  output (Conv1D)             (None, 8192, 1)           106
#
# =================================================================
# Total params: 31,961
# Trainable params: 31,525
# Non-trainable params: 436
# _________________________________________________________________
# Epoch 1/10
# 2023-03-20 19:46:47.179550: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-03-20 19:46:47.621224: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-20 19:46:48.267602: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f4e01c95a80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-03-20 19:46:48.267660: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-03-20 19:46:48.275291: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-03-20 19:46:48.419071: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-20 19:46:48.485864: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-03-20 19:46:48.601035: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-20 19:46:48.784346: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-20 19:46:49.203956: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-20 19:46:49.416142: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-20 19:46:49.820199: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-20 19:46:50.014161: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-20 19:46:50.404634: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-20 19:46:50.593209: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-20 19:46:51.032166: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-20 19:46:51.221593: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
#  3/47 [>.............................] - ETA: 2s - loss: 1.5798 - accuracy: 0.0000e+00
# 2023-03-20 19:46:53.402005: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.0.145, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 47/47 [==============================] - 14s 55ms/step - loss: 0.1651 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 0.0000e+00 - lr: 9.0245e-04
# Epoch 2/10
# 47/47 [==============================] - 2s 39ms/step - loss: 0.0030 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_accuracy: 0.0000e+00 - lr: 8.1259e-04
# Epoch 3/10
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 0.0059 - val_accuracy: 0.0000e+00 - lr: 7.3169e-04
# Epoch 4/10
# 47/47 [==============================] - 2s 40ms/step - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0044 - val_accuracy: 0.0000e+00 - lr: 6.5884e-04
# Epoch 5/10
# 47/47 [==============================] - 2s 38ms/step - loss: 9.3839e-04 - accuracy: 0.0000e+00 - val_loss: 0.0029 - val_accuracy: 0.0000e+00 - lr: 5.9324e-04
# Epoch 6/10
# 47/47 [==============================] - 2s 38ms/step - loss: 7.8934e-04 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00 - lr: 5.3417e-04
# Epoch 7/10
# 47/47 [==============================] - 2s 53ms/step - loss: 6.8833e-04 - accuracy: 0.0000e+00 - val_loss: 0.0012 - val_accuracy: 0.0000e+00 - lr: 4.8099e-04
# Epoch 8/10
# 47/47 [==============================] - 2s 40ms/step - loss: 6.1514e-04 - accuracy: 0.0000e+00 - val_loss: 8.1144e-04 - val_accuracy: 0.0000e+00 - lr: 4.3310e-04
# Epoch 9/10
# 47/47 [==============================] - 2s 38ms/step - loss: 5.5963e-04 - accuracy: 0.0000e+00 - val_loss: 6.2768e-04 - val_accuracy: 0.0000e+00 - lr: 3.8998e-04
# Epoch 10/10
# 47/47 [==============================] - 2s 39ms/step - loss: 5.1608e-04 - accuracy: 0.0000e+00 - val_loss: 5.3683e-04 - val_accuracy: 0.0000e+00 - lr: 3.5115e-04
# 13/13 [==============================] - 1s 16ms/step
# (409, 8192, 1)
# [[[-0.06309791]
#   [ 0.6096873 ]
#   [-0.2620872 ]
#   ...
#   [-0.2990512 ]
#   [ 0.02838927]
#   [-0.19728644]]
#
#  [[-0.09625296]
#   [ 0.5368314 ]
#   [-0.33594245]
#   ...
#   [-0.34741122]
#   [-0.09116623]
#   [-0.12944779]]
#
#  [[-0.15070657]
#   [ 0.41955364]
#   [-0.4259279 ]
#   ...
#   [-0.24594128]
#   [-0.18193465]
#   [-0.06549034]]
#
#  ...
#
#  [[ 0.22899069]
#   [-0.23834012]
#   [ 0.46715683]
#   ...
#   [ 0.14629045]
#   [ 0.26770756]
#   [-0.00732844]]
#
#  [[ 0.27053323]
#   [-0.0993607 ]
#   [ 0.454782  ]
#   ...
#   [-0.00417789]
#   [ 0.19954136]
#   [-0.02885007]]
#
#  [[ 0.264876  ]
#   [ 0.01265278]
#   [ 0.42691964]
#   ...
#   [-0.03259287]
#   [ 0.08234774]
#   [-0.07372858]]]

# %%
print(noise_predict.shape, y_test_batch.shape, strain_mean, strain_std)
print(noise_predict.min(), noise_predict.max())
print(y_test_batch.min(), y_test_batch.max())
# Out:
# (409, 8192, 1) (409, 8192) 7.500541609073216e-23 1.289558418580469e-19
# -0.6927861 0.7198659
# -5.236755661411389e-19 6.152436802843998e-19

# %%
model_noise_predict = noise_predict

# %%
# Before un-normalization 
plt.plot(model_noise_predict[0][:,0])
plt.title('Before inversing z-score')
plt.show()

#Un-normalizing Data
for i in range(noise_predict.shape[0]):
    noise_predict[i] = (model_noise_predict[i] * strain_std) + strain_mean
plt.plot(noise_predict[0][:,0])
plt.title('After inversing z-score')
plt.show()

plt.plot(model_noise_predict[0][:,0], label = 'Normalized')
plt.plot(noise_predict[0][:,0], label = 'Un-normalized')
plt.legend()
plt.show()

# %%
#eight-order Butterworth bandpass filter
N = 8
Wn = [0, 0.3] #Band-pass [low end, high end]
filter_type = "bp"
fs = Wn[1]/2
b, a = signal.butter(N, Wn, filter_type, analog=True)
w, h = signal.freqs(b, a)
butter_sos = signal.butter(N, Wn, filter_type, fs , output = 'sos')

# %%
for idx in range(len(noise_predict)):
        noise_predict[idx] = signal.sosfilt(butter_sos, noise_predict[idx])

# %%
plt.plot(noise_predict[0][:,0])
plt.title('8th order Butterworth Filter')
plt.show()

# %%
print(noise_predict.shape, y_test_batch.shape)
# Out:
# (409, 8192, 1) (409, 8192)

# %%
noise_predict.shape[0]*noise_predict.shape[1]
# Out:
# 3350528

# %%
noise_predict = noise_predict.reshape(noise_predict.shape[0]*noise_predict.shape[1])
y_test_batch = y_test_batch.reshape(y_test_batch.shape[0]*y_test_batch.shape[1])

# %%
#anti-imaging filter not needed because all samples are sampled at the same rate?

#subtracting from full bandwidth strain
clean_strain = y_test_batch - noise_predict
plt.plot(clean_strain)
plt.title('Clean Strain')
plt.show()

# %%
P_signal = logsumexp(np.mean(clean_strain ** 2))
P_noise = logsumexp((np.mean(noise_predict) ** 2))
print(P_signal, P_noise)
# Out:
# 1.663922099907917e-38 1.8426649754374405e-52

# %%
SNR_dB = 10*math.log10(P_signal/P_noise)
print('SNR_dB =',round(SNR_dB,2))
# Out:
# SNR_dB = 139.56

# %%
## Calculating Power Spectral Denisty (PSD) and Amplitude Spectral Density (ASD)

PSD_data_clean = plt.psd(clean_strain, Fs = 4096, scale_by_freq=False)
PSD_data_clean = np.asarray(PSD_data_clean)
plt.xscale("log")
plt.title('PSD of Clean Strain')
# Out:
# Text(0.5, 1.0, 'PSD of Clean Strain')

# %%
PSD_data_orig = plt.psd(y_test_batch.reshape(clean_strain.shape), Fs = 4096, scale_by_freq=False,)
PSD_data_orig = np.asarray(PSD_data_orig)
plt.xscale("log")
plt.title('PSD of Original Data')
# Out:
# Text(0.5, 1.0, 'PSD of Original Data')

# %%
plt.plot(PSD_data_clean[1],np.asarray(PSD_data_orig[0])- np.asarray(PSD_data_clean[0]))
plt.xscale('log')
plt.title('Difference')
# Out:
# Text(0.5, 1.0, 'Difference')

# %%
ASD_data_clean = np.sqrt(PSD_data_clean[0])
plt.semilogx(PSD_data_clean[1],np.log(ASD_data_clean))
plt.grid()
plt.xlabel('Frquency')
plt.ylabel('Amplitude Spectral Density (dB)')
plt.title('ASD of Clean Strain')
# Out:
# Text(0.5, 1.0, 'ASD of Clean Strain')

# %%
ASD_data_orig = np.sqrt(PSD_data_orig[0])
plt.semilogx(PSD_data_orig[1],np.log(ASD_data_orig))
plt.grid()
plt.xlabel('Frquency')
plt.ylabel('Amplitude Spectral Density (dB)')
plt.title('ASD of Original Strain')
# Out:
# Text(0.5, 1.0, 'ASD of Original Strain')

# %%
plt.plot(PSD_data_clean[1],np.asarray(ASD_data_orig)- np.asarray(ASD_data_clean))
plt.xscale('log')
plt.title('Difference')
# Out:
# Text(0.5, 1.0, 'Difference')
